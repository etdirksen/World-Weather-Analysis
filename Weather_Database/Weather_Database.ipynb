# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import pprint
from datetime import datetime
from citipy import citipy
import time
import csv
from config import weather_api_key

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
base_url = f'https://api.openweathermap.org/data/2.5/weather?&appid={weather_api_key}&units=imperial'

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = base_url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]['description']
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint-philippe
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | namtsy
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | severnyy
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | yuli
# Processing Record 8 of Set 1 | avarua
# Processing Record 9 of Set 1 | porto novo
# Processing Record 10 of Set 1 | bontang
# Processing Record 11 of Set 1 | mvangue
# Processing Record 12 of Set 1 | tiksi
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | skegness
# Processing Record 15 of Set 1 | talnakh
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | ambanja
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | castro
# Processing Record 20 of Set 1 | baiao
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | barrow
# ...

# %%
# Reorder the columns to match the challenge order.
reordered = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Date', 'Current Description']
city_data_df = city_data_df[reordered]
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0    Saint-Philippe      RE -21.3585   55.7679     71.19        77
# 1       Yellowknife      CA  62.4560 -114.3525     67.19        67
# 2            Namtsy      RU  62.7161  129.6658     55.49        98
# 3         Busselton      AU -33.6500  115.3333     65.03        93
# 4          Severnyy      RU  50.6770   36.5532     84.24        39
# ..              ...     ...      ...       ...       ...       ...
# 677  Port Macquarie      AU -31.4333  152.9167     44.89        75
# 678        Cananeia      BR -25.0147  -47.9267     82.22        45
# 679          Shache      CN  38.4167   77.2406     79.84        45
# 680           Banyo      CM   6.7500   11.8167     66.00        97
# 681         Solenzo      BF  12.1833   -4.0833     86.23        65
#
#      Cloudiness  Wind Speed                 Date Current Description
# 0            39       13.11  2022-08-15 16:11:51    scattered clouds
# ...

# %%
# Export the dataframe as a .csv file in the current folder. Label the index with "City_ID".
output_data_file = 'weather_database.csv'
city_data_df.to_csv(output_data_file, index_label = 'City_ID')
